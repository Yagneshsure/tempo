# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My_Fist_Jupyetr_notebook

# %% [markdown]
# ### This is my first code in Jupyter notebook

# %% [markdown]
# ## The languages used in Data Science are:
# * Python
# * R
# * SQL
# * Nosql

# %% [markdown]
# ### Some of the libaries used in data science are:
# * Pandas
# * Numpy
# * Scikit-learn
# * matplotlib
# * Seaborn
# * Plotly
# * TenserFlow
# * NLTK

# %% [markdown]
# ### Markdown cell with a table of Data Science tools:
#
# | Data Science Tools    |
# |-----------------------|
# | Jupyter Notebook      |
# | RStudio               |
# | Apache Spark          |
# | TensorFlow            |
# | Scikit-learn          |
# | PyCharm               |
# | Tableau               |
# | Power BI              |
# | Hadoop                |
# | KNIME                 |
# | RapidMiner            |
# | Microsoft Azure ML    |
# | Google Colab          |
# | IBM Watson Studio     |

# %% [markdown]
# ## Introduction arithmetic expression examples.

# %%
a = 14
b = 28

### Addition

add = a + b

### multiplication 

sum = a * b


print(add)
print(sum)
# Out:
# 42
# 392

# %%
# Exercise 9 - Create a code cell to convert minutes to hours.
min = int(input("Enter the minutes:"))

hr_convertion = min / 60

min_in_Hrs = print(f"For {min} minutes, the equivalent in hours is {hr_convertion:.2f} Hours")

print(min_in_Hrs)
# Out:
# For 36673 minutes, the equivalent in hours is 611.22 Hours
# None

# %% [markdown]
# ### Objectives
#
# 1. Understand the basics of data science and its various tools.
# 2. Learn how to manipulate and analyze data using Python .
# 3. Gain proficiency in using data visualization tools to present data insights.
# 4. Develop skills in machine learning techniques and algorithms.
# 5. Implement real-world data science projects to solve complex problems.
# 6. Enhance programming skills and best practices in data science workflows.

# %% [markdown]
# ## Author
#
# Yagnesh Ravi D P Sure
